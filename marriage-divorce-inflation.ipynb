# %% [markdown]
# ## Preface
# First time I went to [kaggle website](https://kaggle.com), I randomly searched "Iran" in the datasets section. because I had no idea of project it is that I want to do, I never had interest in data mining even though I've been coding for years.
#
# I saw some data about marriage and divorce in Iran. It got me thinking, How mariage, divorce, and inflation are related in Iran.
#
# As the RTL-markdown extension for vscode didn't work for me, I'm writing the documentations in English. Sorry if there are some mistakes in the documentations.

# %% [markdown]
# ## Preparing the enviroment and playing with the data
# After logging in to kaggle, I downloaded some data called "[GDP per captia between 1960 and 2021](https://www.kaggle.com/datasets/gwenaelmouthuy/gdp-per-capita-between-1960-and-2021/)".This data describes the economic growth of each person in one nation. I think this would be a more solid metric in comparison to inflation alone.
#
# Then I started a jupyter lab server (as I couldn't sign in to google collab),  copied the data into the jupyter lab directory (folder).
#
# I started coding. Imported pandas as pd, and pyplot from matplotlib as plt. Then set the GDP per capita csv file's path to a variable.
#
# Then we select the row where the country equals "Iran".

# %%
import pandas as pd
import matplotlib.pyplot as plt 

gdp_file_path = "gdppercapita_us_inflation_adjusted.csv"

gdp_df = pd.read_csv(gdp_file_path)
# selecting country==Iran row and 
# ignoring country (first) column
gdp_iran_df = df[df['country'] == "Iran"].iloc[:, 1:]
gdp_iran_df
# Out:
#     1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2012  \
# 88  2350  2520  2650  2750  2900  3300  3570  3860  4290  4820  ...  5180
#
#     2013  2014  2015  2016  2017  2018  2019  2020  2021
# 88  5030  5180  4990  5330  5400  5210  5020  5140  5340
#
# [1 rows x 62 columns]

# %%
marriage_file_path = "Marriage and divorce in Iran.csv"
marriage_df = pd.read_csv(marriage_file_path)
def togregorian(year):
  year = year.replace("(2)", "")
  return int(year)+621
marriage_df["Year"] = marriage_df["Year"].apply(togregorian)
marriage_df["divorce/marriage"] = marriage_df["divorce(country)"]/marriage_df["marriage(country)"]
marriage_df
# Out:
#     Year  marriage(country)  divorce(country) marriage(city) divorce(city)  \
# 0   1979             302667             21170         173963         15445
# 1   1980             337119             23987         196029         19293
# 2   1981             294499             24423         183546         20449
# 3   1982             353944             31221         215077         25773
# 4   1983             410799             35867         259433         30808
# 5   1984             384876             35178         247253         29047
# 6   1985             408282             38983         263883         31869
# 7   1986             340342             35211         225011         29379
# 8   1987             346652             33433         225566         27588
# 9   1988             361945             33114         239095         26893
# 10  1989             458708             33943         295982         27626
# ...

# %%
plt.figure(figsize=(32, 12))
plt.plot(iran_df.columns[19:], iran_df.values[0][19:], label="GDP")
plt.plot(marriage_df.Year, marriage_df["divorce/marriage"], label="divorce/marriage")
plt.legend()
plt.show()
iran_df.columns[19:]
# Out:
# Index(['1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')
